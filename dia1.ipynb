# %%
print ("hola mundo")
# Out:
# hola mundo

# %%
#challenge 1
nombre = "tobias"
edad = 19
ciudad = "lambare"
print(nombre, edad, ciudad)
# Out:
# tobias 19 lambare

# %% [markdown]
# Suma: asignar dos números en dos variables diferentes cantidad_de_manzanas y cantidad_de_naranjas. Luego sumar ambas variables en cantidad_de_frutas. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable frutas_vendidas. Luego, asignar la resta entre cantidad_de_frutas y frutas_vendidas a la variable frutas_restantes. Imprimir la última variable.

# %%
cantidad_de_manzanas = 5
cantidad_de_naranjas = 5
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print ("la suma de 5 narajas y 5 manzanas da", cantidad_de_frutas)

frutas_vendidas = 6
cantidad_de_frutas = cantidad_de_frutas - frutas_vendidas 
print ("se vendieron 6 frutas, la cantidad de frutas sobrantes son", cantidad_de_frutas)
# Out:
# la suma de 5 narajas y 5 manzanas da 10
# se vendieron 6 frutas, la cantidad de frutas sobrantes son 4

# %%
#Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
#variables
nombre = "Diego"
apellido = "Rojas"
espacio = " "

#impreción en pantalla
print("hola, mi nombre es " + nombre + " " + apellido + "." + espacio + "Mucho gusto")
# Out:
# hola, mi nombre es Diego Rojas. Mucho gusto

# %%
nombre = input("escribe tu nombre ")
print(nombre)
# Out:
# si

# %%
def preparar_la_carne():
    print("preparando carne para condimentarla")
    print("condimentando la carne")
    print("cocinando la carne")
preparar_la_carne()
preparar_la_carne()
preparar_la_carne()
# Out:
# preparando carne para condimentarla
# condimentando la carne
# cocinando la carne
# preparando carne para condimentarla
# condimentando la carne
# cocinando la carne
# preparando carne para condimentarla
# condimentando la carne
# cocinando la carne

# %%
elemento = "ps5"
elemento_a_comprar = input("cuales son las caracteristicas del articulo que necesitas ")
print(elemento_a_comprar)
def elemento_a_comprar():
    print(elemento)

elemento_a_comprar()
# Out:
# asdfjkjafhlskjfh
# ps5
