# %%
print("hola mam")
# Out:
# hola mam

# %%
#funcion
def saludar():
    print("hola mam")
saludar()
# Out:
# hola mam

# %%
#variable
palabra = "hola"

#funcion          
def imprimir_palabra( ):
    print(palabra)
imprimir_palabra()
# Out:
# hola

# %%
# fincion que recine 2 numeros y suma 

# definir 2 variables con int(input()), numero1 y numero2 (fuera de la funcion)
# definir funcion sumar(n1, n2):
    #opcion1: n3 = n1 + n2
        #opcion1: print(n3)

    #opcion2: print(n1 + n2)
# ejecutar a la funcion sumar()

numero1 = int(input("ingresa numero"))
numero2 = int(input("ingresa numero"))

def sumar(n1, n2):
    n3 = n1 + n2
    print(n3)
sumar(numero1, numero2)
# Out:
# 12

# %%
letra1 = input('ingrese una letra')
letra2 = input("letra ingrse otra letra")

def comparar(l1, l2):
     if  l1 == l2:
        print("las letras son iguales")
     else:
        print("las letras son diferentes")
comparar(letra1, letra2)
# Out:
# las letras son diferentes

# %%
# return: retornar, devolver

# %%
# tipe ayuda a saber que tipo de datos tenemos

# %%
def retirar_dinero(dinero):
    print(f"retirando {dinero}")

retirar_dinero(60000)
# Out:
# retirando 60000

# %% [markdown]
# Challenge 3 🤺 - 15m
# Crear una función que reciba dos parámetros (una palabra y un número), y que retorne True si el número es igual a la cantidad de letras de la palabra. En caso contrario, que retorne False.
#
# Pista: cantidad de letras de una palabra en python

# %%
## crear una funcion que reciba parametros (una palabra y un numero) 
palabraa = input("escribe una palabra ")
numero = int(input("ingrese un numero "))
def compara(palabraa, numero):
    if len(palabraa)
#que retorne true si el numero es = a la cantidad de letras o si no falso
# Out:
#   Cell In[38], line 7
#     #que retorne true si el numero es = a la cantidad de letras o si no falso
#                                                                               ^
# SyntaxError: incomplete input

# %%
#crear una funcion que revise si tiene una letra 
#si no tiene, retornar la letra en [] de lo contrario retornar solo la letr 
palabra = input("ingrese una palabra")
letra = input("ingrese la letra a buscar")
def buscar(a, b):
    if letra in palabra:
        return '[{letra}]'
    else:
        return 
buscar(palabra, letra)
# Out:
# '[o]'

# %% [markdown]
# ### definii una variable palabra+ input()
# ### convertir palabra a lista con lista_de_palanra + list(palabra)
#
# ### creamosotra lista llamada: palabras_ingresados + []
# ### palabras_ingresadas.apend(lista_de_palabras)
#
# ### pronar un bucle que repita 3 veces el proceso siguiente

# %%
# Definir una variable palabra = input()
# Convertir palabra a lista con lista_de_palabra = list(palabra)
# Creamos otra lista llamada: palabras_ingresadas = []
# palabras_ingresadas.append(lista_de_palabra)
# Probar un bucle que repita 3 veces el proceso seguiente: 

palabras_ingresadas = []
for i in range(1):
    palabra = input("Ingresar palabra")
    lista_usuario = list(palabra)
    palabras_ingresadas.append(lista_usuario)
    print(palabras_ingresadas)
# Out:
# [['j', 'h', 'k']]

# %%
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
def hola():
    for x in lista:
        print(x)
hola()
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
lista=[['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
def dar_enter():
    for i in lista:
        print(f"{i}\n")
dar_enter()
# Out:
# ['h', 'o', 'l', 'i', 's']
#
# ['h', 'e', 'l', 'l', 'o']
#
# ['h', 'a', 'l', 'l', 'o']
