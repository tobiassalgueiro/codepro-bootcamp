# %%
print("hola")
# Out:
# hola

# %% [markdown]
# Challenge 1 🤺 10m
# Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario.
#
# Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

# %%
#crear un dicionario vacio
#crear un input para llenarlo con informacion de alguien 
#cada vez que se escriba algo en el diccionario debe imprimirse el contenido de tal

# %%
diccionario = {}
print(diccionario)
              
diccionario["nombre"] = input("nombre")
print(diccionario)

diccionario["apellido"] = input("apellido")
print(diccionario)

diccionario["edad"] = input("edad")
print(diccionario)

diccionario["sexo"] = input("sexo")
print(diccionario)

diccionario["di"] = input("direccion")
print(diccionario)

diccionario["direccion"] = input("direccion")
print(diccionario)
# Out:
# {}
# {'nombre': 'tobias'}
# {'nombre': 'tobias', 'apellido': 'salgueiro'}
# {'nombre': 'tobias', 'apellido': 'salgueiro', 'edad': '19'}
# {'nombre': 'tobias', 'apellido': 'salgueiro', 'edad': '19', 'direccion': 'lambare'}

# %% [markdown]
# Challenge 2 🤺 - 20 min
# Crear una tarjeta personal. El usuario (mediante input) puede elegir:
#
# Crear datos nuevos
# Modificar datos
# Eliminar datos

# %%
tarjeta_personal = {"nombre": "tobias salgueiro", "edad": "19", "email": "tobiassalgueiro24@gmail.com", "direccion": "lambare"

}
def modificar():
    print(tarjeta_personal)
    if tarjeta_personal["nombre"]:
     tarjeta_personal["nombre"] = input("ingrese nombre")
    print(tarjeta_personal)
    if tarjeta_personal["edad"]:
     tarjeta_personal["edad"] = input("ingrese su edad")
    print(tarjeta_personal)
# Out:
# {'nombre': 'tobias salgueiro', 'edad': '19', 'email': 'tobiassalgueiro24@gmail.com', 'direccion': 'lambare'}
# {'nombre': 'tobias salgueiro', 'edad': '19', 'email': 'tobiassalgueiro24@gmail.com', 'direccion': 'lambare'}
# {'nombre': '', 'edad': '19', 'email': 'tobiassalgueiro24@gmail.com', 'direccion': 'lambare'}
# {'nombre': '', 'edad': '', 'email': 'tobiassalgueiro24@gmail.com', 'direccion': 'lambare'}

# %%
contactos ={}
print(f"ingrese la accion que quiere realizar 1- mostrar 2-crear 3modificar")

# %%
class Perro: #clase: como un molde 
    especie = "canina" #atributo de clase: todos los objetos tendran 

    def __init__(self, nombre, raza, color): #atributo de instancia 
        self.nombre = nombre
        self.raza = raza
        self.color = color
perro1 = Perro("firulais", "mestizo", "marron") #objeto creado
print(Perro.especie)
# Out:
# canina

# %% [markdown]
# Challenge 🤺  - 15 min
# Crear una clase animales que tenga atributo de clase y de instancia.
#
# Atributos de clase: especie.
# Atributos de instancia: nombre & color
# .
# Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
# Ejemplo: "Me llamo {nombre} y soy un ave de color {color}".

# %%
class Pajarito:
    especie = "aves"
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color
pajarito1 = Pajarito("pajarito lindo", "azul")
print(f"hola me llamo {pajarito1.nombre} y soy color {pajarito1.color}" )
# Out:
# hola me llamo pajarito lindo y soy color azul

# %%
class superheroe: 
    especie = "superhumanos"
#atributos de instancia
    def __init__(self, nombre):
        self.nombre = nombre
    #definir otras acciones de la clase
    def rayos_laser(self):
        print("tiro rayos laser rojos")

    def volar(self, km):
        print(f"estoy volando a km {km}")

    def alzar_objetos(slf, objeto, kg):
        print(f"puedo alzar un {objeto} de {kg} Kg")
#instaciar objetos
superheroe1 = superheroe("BARTO")
print(superheroe1.volar(120))
# Out:
# estoy volando a km 120
# None

# %%
class Perro:

    especie= 'perro'

    def init(self, nombre, color, caracteristica):
        self.nombre= nombre
        self.color= color
        self.caracteristica= caracteristica

#crear el objeto
firulais= Perro('firulais', 'marron', 'ladra')
print(f'cuando yo hablo Maximo el {firulais.especie} {firulais.color} {firulais.caracteristica}')

momo= Perro('Momo', 'negro', 'mueve la cola')
print(f'cuando yo digo PASEO! Momo el {momo.especie} {momo.color} {momo.caracteristica}')

# %%
class AnimalDeGranja:
    #atributo de clase
    tipo = "animal de granja"

    #atributos de instancia 
    def __init__(self, nombre, color, sonido):
        self.nomnre = nombre
        self.color = color
        self,sonido = sonido
    
    #metodos (acciones de la clase )
    def hablar(self):
        print(f"hablo y digo {self.sonido}")

# %% [markdown]
# Challenge 3🤺 - 15 min
# Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.
#
# Observación: Editar las clases hijas para que no se inicialicen.

# %%
class Vehiculos:
    tipo = "vehiculos a motor"

    def __init__(self, moto, auto, sonido):
        self.auto = auto
        self.moto = moto
        self.sonido = sonido

    def acelerar(self):
        print(f"el auto acelera y hace {self.sonido}")
        sonido = "ruuuuummmmmmm"
    
    def frenada(self):
        print(f"frene y hizo {self.sonido}")
        sonido = "hiiiiiiiih"
moto = Vehiculos("no es un auto", "star", "el canho de escape hace")
print(f"la moto freno {Vehiculos.acelerar}")
# Out:
# la moto freno <function Vehiculos.acelerar at 0x000002A209115A80>

# %%
#Clase MADRE:

class Profesor:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad
        
#Clase hija:
class Estudiante (Profesor):
    calificacion= 0 

estudiante1 = Estudiante("Ana", 20)
profesor1 = Profesor ("Carlos", 45)

#Clase hija:
class Egresado (Profesor):
    calificacion= 0 

Egresado = Egresado ("Matias", 22)
profesor1 = Profesor ("Carlos", 45)


#Mostrar atributos heredados
print("Estudiante:")
print(estudiante1.nombre)
print(estudiante1.edad)

   
print("\nEgresado")
print(Egresado.nombre)
print(Egresado.edad)
# Out:
# Estudiante:
# Ana
# 20
#
# Egresado
# Matias
# 22

# %% [markdown]
# Challenge 4 🤺 - 20 min
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.
#
# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

# %%
#crear dos clases y en las clases personajes 
#deben tener dos metodos al menos en cada clase
#deben estar representados en una frase 


class Supers:
    def __init__(self, poder, habilidad_especial):
        self.poder = poder
        self.habilidad_especial = habilidad_especial
    
class Super1(Supers):
    nombre = "super man"
    habilidad_especial = "volar"

class Super2(Supers):
    nombre = "batman"
    habilidad_especial = "no tengo poderes pero si plata"
print(f"yo soy {Super2.nombre} y {Super2.habilidad_especial}. y yo soy {Super1.nombre} y puedo {Super1.habilidad_especial}")
# Out:
# yo soy batman y no tengo poderes pero si plata. y yo soy super man y puedo volar
